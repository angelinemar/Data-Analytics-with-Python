# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
# 1a.cheeck the dimension of the dataframe
ons = pd.read_csv("onsite-mobile_dataset.csv")
ons.head()
# Out:
#    Unnamed: 0                            Name    Brand  \
# 0           0  OnePlus 7T Pro McLaren Edition  OnePlus
# 1           1                   Realme X2 Pro   Realme
# 2           2               iPhone 11 Pro Max    Apple
# 3           3                       iPhone 11    Apple
# 4           4                    LG G8X ThinQ       LG
#
#                     Model  Battery capacity (mAh)  Screen size (inches)  \
# 0  7T Pro McLaren Edition                    4085                  6.67
# 1                  X2 Pro                    4000                  6.50
# 2       iPhone 11 Pro Max                    3969                  6.50
# 3               iPhone 11                    3110                  6.10
# 4               G8X ThinQ                    4000                  6.40
#
#   Touchscreen  Resolution x  Resolution y  Processor  ...  Rear camera  \
# 0         Yes          1440          3120          8  ...         48.0
# ...

# %%
# 1b. perform basic statistic using describe function 
ons.describe(include='all').T

# Specs shown described with the calculation of min, median, etc
# Out:
#                          count unique                             top  freq  \
# Unnamed: 0              1359.0    NaN                             NaN   NaN
# Name                      1359   1359  OnePlus 7T Pro McLaren Edition     1
# Brand                     1359     76                           Intex   117
# Model                     1359   1321                              V5     4
# Battery capacity (mAh)  1359.0    NaN                             NaN   NaN
# Screen size (inches)    1359.0    NaN                             NaN   NaN
# Touchscreen               1359      2                             Yes  1342
# Resolution x            1359.0    NaN                             NaN   NaN
# Resolution y            1359.0    NaN                             NaN   NaN
# Processor               1359.0    NaN                             NaN   NaN
# RAM (MB)                1359.0    NaN                             NaN   NaN
# ...

# %%
# 1c. show the datatype each column 
ons.info()

# Datatype can be seen as shown from the column Dtype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1359 entries, 0 to 1358
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              1359 non-null   int64
#  1   Name                    1359 non-null   object
#  2   Brand                   1359 non-null   object
#  3   Model                   1359 non-null   object
#  4   Battery capacity (mAh)  1359 non-null   int64
#  5   Screen size (inches)    1359 non-null   float64
#  6   Touchscreen             1359 non-null   object
#  7   Resolution x            1359 non-null   int64
#  8   Resolution y            1359 non-null   int64
#  9   Processor               1359 non-null   int64
#  10  RAM (MB)                1359 non-null   int64
#  11  Internal storage (GB)   1359 non-null   float64
#  12  Rear camera             1359 non-null   float64
#  13  Front camera            1359 non-null   float64
# ...

# %%
#1d. show the first 7 rows and the last 7 rows 

# The first 7 rows
ons.head(7)
# Out:
#    Unnamed: 0                            Name    Brand  \
# 0           0  OnePlus 7T Pro McLaren Edition  OnePlus
# 1           1                   Realme X2 Pro   Realme
# 2           2               iPhone 11 Pro Max    Apple
# 3           3                       iPhone 11    Apple
# 4           4                    LG G8X ThinQ       LG
# 5           5                      OnePlus 7T  OnePlus
# 6           6                  OnePlus 7T Pro  OnePlus
#
#                     Model  Battery capacity (mAh)  Screen size (inches)  \
# 0  7T Pro McLaren Edition                    4085                  6.67
# 1                  X2 Pro                    4000                  6.50
# 2       iPhone 11 Pro Max                    3969                  6.50
# 3               iPhone 11                    3110                  6.10
# 4               G8X ThinQ                    4000                  6.40
# 5                      7T                    3800                  6.55
# ...

# %%
# The last 7 rows
ons.tail(7)
# Out:
#       Unnamed: 0                         Name     Brand               Model  \
# 1352        1352                     Xolo Era      Xolo                 Era
# 1353        1353          Intex Aqua Y2 Ultra     Intex       Aqua Y2 Ultra
# 1354        1354                Intex Aqua A2     Intex             Aqua A2
# 1355        1355  Videocon Infinium Z51 Nova+  Videocon  Infinium Z51 Nova+
# 1356        1356                Intex Aqua Y4     Intex             Aqua Y4
# 1357        1357              iBall Andi4 B20     iBall           Andi4 B20
# 1358        1358          iBall Andi Avonte 5     iBall       Andi Avonte 5
#
#       Battery capacity (mAh)  Screen size (inches) Touchscreen  Resolution x  \
# 1352                    2100                   5.0         Yes           854
# 1353                    1400                   4.0         Yes           480
# 1354                    1500                   4.0         Yes           480
# ...

# %%
# 2.1. Data Formating. Convert Indian Rupee (INR) to Indonesian Rupiah (IDR) with kurs: 1 INR equals to 186.38 IDR (10%)

# convert into IDR
ons['price in Indonesian'] = ons['Price'] * 186.38
ons.head(5)
# Out:
#    Unnamed: 0                            Name    Brand  \
# 0           0  OnePlus 7T Pro McLaren Edition  OnePlus
# 1           1                   Realme X2 Pro   Realme
# 2           2               iPhone 11 Pro Max    Apple
# 3           3                       iPhone 11    Apple
# 4           4                    LG G8X ThinQ       LG
#
#                     Model  Battery capacity (mAh)  Screen size (inches)  \
# 0  7T Pro McLaren Edition                    4085                  6.67
# 1                  X2 Pro                    4000                  6.50
# 2       iPhone 11 Pro Max                    3969                  6.50
# 3               iPhone 11                    3110                  6.10
# 4               G8X ThinQ                    4000                  6.40
#
#   Touchscreen  Resolution x  Resolution y  Processor  ...  Front camera  \
# 0         Yes          1440          3120          8  ...          16.0
# ...

# %%
# 2.2. What is the top 10 of the most expensive phone on the dataset? (use bar chart)

# describe datas
ons["Price"].describe()
# Out:
# count      1359.000000
# mean      11465.825607
# std       13857.497077
# min         494.000000
# 25%        4763.500000
# 50%        6999.000000
# 75%       11999.000000
# max      174990.000000
# Name: Price, dtype: float64

# %%
# filter brand
onsfilter = ons[ons['Brand'].isin(['Asus', 'Apple', 'Samsung', 'Huawei', 'Xiaomi'])]

# %%
# mean and median
ons2 = onsfilter.groupby('Brand').agg({
    'Price' : ['mean', 'median']})
ons2.head(100)
# Out:
#                 Price
#                  mean   median
# Brand
# Apple    45510.470588  36999.0
# Asus     14926.459459   8891.0
# Huawei   38564.750000  41498.5
# Samsung  22500.069307  13980.0
# Xiaomi    9993.808511   8490.0

# %%
# show plot 
ex = ons.groupby('Brand').agg({'Price' : 'mean'})
ex.head(10)
# Out:
#                 Price
# Brand
# Apple    45510.470588
# Asus     14926.459459
# Huawei   38564.750000
# Samsung  22500.069307
# Xiaomi    9993.808511

# %%
# the most expensive phone
colors = sns.color_palette('pastel')[3:4]
sns.histplot(data=ons, x="Price", color= colors)
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Count'>

# %%
# Read CSV into pandas again
data = pd.read_csv("onsite-mobile_dataset.csv")
data.head(1000)
# Out:
#      Unnamed: 0                            Name      Brand  \
# 0             0  OnePlus 7T Pro McLaren Edition    OnePlus
# 1             1                   Realme X2 Pro     Realme
# 2             2               iPhone 11 Pro Max      Apple
# 3             3                       iPhone 11      Apple
# 4             4                    LG G8X ThinQ         LG
# ..          ...                             ...        ...
# 995         995                   Panasonic P71  Panasonic
# 996         996                   Zopo Color F2       Zopo
# 997         997                 Motorola Moto M   Motorola
# 998         998                          Lyf F8        Lyf
# 999         999                   Huawei Mate 9     Huawei
#
#                       Model  Battery capacity (mAh)  Screen size (inches)  \
# 0    7T Pro McLaren Edition                    4085                  6.67
# 1                    X2 Pro                    4000                  6.50
# ...

# %%
# Filter top price
df = pd.DataFrame(data)    
 
brand = df['Brand'].head(10)
price = df['Price'].head(10)
 
# Figure Size
fig = plt.figure(figsize =(10, 7))
 
# Horizontal Bar Plot
plt.bar(brand[0:10], price[0:10])
 
# Show Plot
plt.show(1000)

# The top expensive phone goes to Apple

# %%
data2 = data[data['Brand'] == 'Apple']

# %%
data2.groupby('Brand').agg({
    'Price' : 'max'}).reset_index().sort_values(by='Price', ascending=True).head(10)
# Out:
#    Brand   Price
# 0  Apple  106900

# %%
# 2.3. Distribution of all phone data
colors = sns.color_palette("Set2")[0:1]
sns.histplot(data=data, y='Brand', color= colors)
# Out:
# <AxesSubplot:xlabel='Count', ylabel='Brand'>

# %%
# 3. Exploratory Data Analysis. Apply Zscore analysis and find the outlier. How many percent(%) outlier data compares to all data? (20%)

data = data[['Front camera']].fillna(data.mean())
data
# Out:
#       Front camera
# 0             16.0
# 1             16.0
# 2             12.0
# 3             12.0
# 4             32.0
# ...            ...
# 1354           0.3
# 1355           5.0
# 1356           2.0
# 1357           0.3
# 1358           0.0
#
# [1359 rows x 1 columns]

# %%
from scipy import stats
import numpy as np

stats.zscore(data)
# Out:
#       Front camera
# 0         1.424097
# 1         1.424097
# 2         0.788484
# 3         0.788484
# 4         3.966552
# ...            ...
# 1354     -1.070686
# 1355     -0.323840
# 1356     -0.800550
# 1357     -1.070686
# 1358     -1.118357
#
# [1359 rows x 1 columns]

# %%
data_baru =data[(np.abs(stats.zscore(data, nan_policy='omit')) < 3).all(axis=1)]
data_baru.shape
# Out:
# (1334, 1)

# %%
# Zscore 

data_baru.plot(kind='box', figsize=(5,5))
plt.show

# From the z-score process below, the interquartile range of the car is between 0 - 16.
# Average cars are on 3 - 7 range.
# However, some outliers are indicated to those with significant engine size with the range of 20 - 25.
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# 4. Data Preprocessing and Preparation. Perform Binning for Prices column with this criteria: (20%)
# a. Below 5 million rupiah categorized as Low
# b. Between 5 million and 10 million categorized as Medium
# c. Above 100 million rupiah categorized as High

# %%
# Read CSV into pandas again
data = pd.read_csv("onsite-mobile_dataset.csv")
data.head(1000)
# Out:
#      Unnamed: 0                            Name      Brand  \
# 0             0  OnePlus 7T Pro McLaren Edition    OnePlus
# 1             1                   Realme X2 Pro     Realme
# 2             2               iPhone 11 Pro Max      Apple
# 3             3                       iPhone 11      Apple
# 4             4                    LG G8X ThinQ         LG
# ..          ...                             ...        ...
# 995         995                   Panasonic P71  Panasonic
# 996         996                   Zopo Color F2       Zopo
# 997         997                 Motorola Moto M   Motorola
# 998         998                          Lyf F8        Lyf
# 999         999                   Huawei Mate 9     Huawei
#
#                       Model  Battery capacity (mAh)  Screen size (inches)  \
# 0    7T Pro McLaren Edition                    4085                  6.67
# 1                    X2 Pro                    4000                  6.50
# ...

# %%
data.head()
# Out:
#    Unnamed: 0                            Name    Brand  \
# 0           0  OnePlus 7T Pro McLaren Edition  OnePlus
# 1           1                   Realme X2 Pro   Realme
# 2           2               iPhone 11 Pro Max    Apple
# 3           3                       iPhone 11    Apple
# 4           4                    LG G8X ThinQ       LG
#
#                     Model  Battery capacity (mAh)  Screen size (inches)  \
# 0  7T Pro McLaren Edition                    4085                  6.67
# 1                  X2 Pro                    4000                  6.50
# 2       iPhone 11 Pro Max                    3969                  6.50
# 3               iPhone 11                    3110                  6.10
# 4               G8X ThinQ                    4000                  6.40
#
#   Touchscreen  Resolution x  Resolution y  Processor  ...  Rear camera  \
# 0         Yes          1440          3120          8  ...         48.0
# ...

# %%
# Data Categorization

size = [0, 5000000, 10000000, 100000000]
category = ['Low', 'Medium', 'High']
data['Category'] = pd.cut(data['Price'], bins = size, labels = category)
data
# Out:
#       Unnamed: 0                            Name     Brand  \
# 0              0  OnePlus 7T Pro McLaren Edition   OnePlus
# 1              1                   Realme X2 Pro    Realme
# 2              2               iPhone 11 Pro Max     Apple
# 3              3                       iPhone 11     Apple
# 4              4                    LG G8X ThinQ        LG
# ...          ...                             ...       ...
# 1354        1354                   Intex Aqua A2     Intex
# 1355        1355     Videocon Infinium Z51 Nova+  Videocon
# 1356        1356                   Intex Aqua Y4     Intex
# 1357        1357                 iBall Andi4 B20     iBall
# 1358        1358             iBall Andi Avonte 5     iBall
#
#                        Model  Battery capacity (mAh)  Screen size (inches)  \
# 0     7T Pro McLaren Edition                    4085                  6.67
# 1                     X2 Pro                    4000                  6.50
# ...
